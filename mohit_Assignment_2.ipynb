# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('1.jfif')
imgplot = plt.imshow(img)
plt.show()

# %%
img1 = mpimg.imread('2.jfif')
img1plot = plt.imshow(img1)
plt.show()
